# %% [markdown]
# ## Exercise 4.7

# %% [markdown]
# ### Importing Libraries

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
# Establish path
path = r'/Users/claireheger/Documents/Instacart Basket Analysis'

# %%
# Importing 'orders_products_merged.pkl'
df_orders_products_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
# Check
orders_products_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0             0             0   2539329        1    prior             1
# 1             1             1   2398795        1    prior             2
# 2             2             2    473747        1    prior             3
# 3             3             3   2254736        1    prior             4
# 4             4             4    431534        1    prior             5
#
#    orders_day_of_week  order_hour_of_day  days_since_last_order  uder_id  \
# 0                   2                  8                    NaN        1
# 1                   3                  7                   15.0        1
# 2                   3                 12                   21.0        1
# 3                   4                  7                   29.0        1
# 4                   4                 15                   28.0        1
#
#    product_id  add_to_cart_order  reordered  Unnamed: 0_y product_name  \
# ...

# %%
# Creating subset

df = orders_products_merged[:1000000]

# %%
# Check

df.shape
# Out:
# (1000000, 19)

# %% [markdown]
# ### If Statements

# %%
# Define price_label function

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Apply function

df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/8z/l2fv2rjx3g7cch1w_zdzyp640000gn/T/ipykernel_642/2732771147.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
# Check max price to confirm
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# ### If statements with the loc() function

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/8z/l2fv2rjx3g7cch1w_zdzyp640000gn/T/ipykernel_642/1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ### If-Statements with For-loops

# %%
# Create new column in dataframe
df_orders_products_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
# Set loop
result = []

for value in df_orders_products_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Add result to dataframe
df_orders_products_merged['busiest_day'] = result

# %%
# Check value counts
df_orders_products_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %% [markdown]
# ## Step 2: New Column for Busiest Days

# %%
# Create new if-statement for-loop for new requirements
result_v2 = []

for value in df_orders_products_merged["orders_day_of_week"]:
  if value == 0 or value == 1:
    result_v2.append("Busiest days")
  elif value == 4 or value == 3:
    result_v2.append("Least busy days")
  else:
    result_v2.append("Regularly busy")

# %%
# Add result to dataframe in new column
df_orders_products_merged['busiest_days'] = result_v2

# %%
# Check
df_orders_products_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0             0             0   2539329        1    prior             1
# 1             1             1   2398795        1    prior             2
# 2             2             2    473747        1    prior             3
# 3             3             3   2254736        1    prior             4
# 4             4             4    431534        1    prior             5
#
#    orders_day_of_week  order_hour_of_day  days_since_last_order  uder_id  ...  \
# 0                   2                  8                    NaN        1  ...
# 1                   3                  7                   15.0        1  ...
# 2                   3                 12                   21.0        1  ...
# 3                   4                  7                   29.0        1  ...
# 4                   4                 15                   28.0        1  ...
#
# ...

# %% [markdown]
# ## Step 3: Value of busiest_days column

# %%
df_orders_products_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy     12916111
# Busiest days       11864412
# Least busy days     7624336
# Name: busiest_days, dtype: int64

# %% [markdown]
# When compared against our initial frequency counts, these values result in the totals for their respective "groupings." The combined count for the most active days corresponds to the sum of value 0 and value 1, while the cumulative count for the least active days corresponds to the sum of value 3 and value 4. This validates the correct functioning of the loop.

# %% [markdown]
# ## Step 4: Busiest Period of the Day Column

# %%
# Check frequency of values in the "order_hour_of_day" column 
df_orders_products_merged['order_hour_of_day'].value_counts()
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# Since the client's request involves categorizing these into three distinct sections, we can arrange the 24-hour day into the following groupings:
#
# Most orders: 10, 11, 14, 15, 13, 12, 16, 9
# Average orders: 17, 8, 18, 19, 20, 7, 21, 22
# Fewest orders: 23, 6, 0, 1, 5, 2, 4, 3

# %%
# Create a for-loop if statement using the above breakdown
hour_of_day = []

for value in df_orders_products_merged["order_hour_of_day"]:
  if value in [10, 11, 14, 15, 13, 12, 16, 9]:
    hour_of_day.append("Most orders")
  elif value in [23, 6, 0, 1, 5, 2, 4, 3]:
    hour_of_day.append("Fewest orders")
  else:
    hour_of_day.append("Average orders")

# %%
# Add result to dataframe as "busiest_period_of_day" column
df_orders_products_merged['busiest_period_of_day'] = hour_of_day

# %%
# Check
df_orders_products_merged[['order_hour_of_day', 'busiest_period_of_day']].head(10)
# Out:
#    order_hour_of_day busiest_period_of_day
# 0                  8        Average orders
# 1                  7        Average orders
# 2                 12           Most orders
# 3                  7        Average orders
# 4                 15           Most orders
# 5                  7        Average orders
# 6                  9           Most orders
# 7                 14           Most orders
# 8                 16           Most orders
# 9                  8        Average orders

# %% [markdown]
# ## Step 5: Printing Frequency

# %%
df_orders_products_merged['busiest_period_of_day'].value_counts()
# Out:
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# These frequencies correspond to the totals of the previously mentioned "unsegmented" frequencies, validating the accurate utilization of the labels.

# %% [markdown]
# ## Export as Pickle File

# %%
df_orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_updated.pkl'))
